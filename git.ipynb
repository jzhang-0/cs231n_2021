# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd drive/MyDrive/courses/cs231n/exp
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/courses/cs231n/exp

# %%
# !git pull origin master
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 3 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/jzhang-0/cs231n_2021
#  * branch            master     -> FETCH_HEAD
#  * [new branch]      master     -> origin/master
# hint: Waiting for your editor to close the file... error: unable to start editor 'editor'
# Not committing merge; use 'git commit' to complete the merge.

# %%
# !git config user.name "jzhang-0"
# !git config user.email "jzhang__1999@outlook.com"
# !git add .
# !git commit -m "update"
# Out:
# [master a829393] add git.ipynb
#  2 files changed, 1 insertion(+), 1 deletion(-)
#  create mode 100644 git.ipynb
#  delete mode 100644 "git.ipynb\357\274\210\345\211\257\346\234\254\357\274\211"

# %%
# !git push
# Out:
# fatal: The current branch master has no upstream branch.
# To push the current branch and set the remote as upstream, use
#
#     git push --set-upstream origin master

# %%
# !git push -u origin master
# Out:
# To https://github.com/jzhang-0/cs231n_2021.git
#  ! [rejected]        master -> master (non-fast-forward)
# error: failed to push some refs to 'https://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@github.com/jzhang-0/cs231n_2021.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
username = "jzhang-0"
git_token = "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"
rep = "cs231n_2021"

# %%
# !git remote rm origin
# !git remote add origin https://{git_token}@github.com/{username}/{rep}.git
# !git remote -v
# !git push -u origin master
# Out:
# origin	https://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@github.com/jzhang-0/cs231n_2021.git (fetch)
# origin	https://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@github.com/jzhang-0/cs231n_2021.git (push)

# %%
# !git push -u origin master
