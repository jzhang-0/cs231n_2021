# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd drive/MyDrive/courses/cs231n/exp
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/courses/cs231n/exp

# %%
# !git pull origin master
# Out:
# From https://github.com/jzhang-0/cs231n_2021
#  * branch            master     -> FETCH_HEAD
#  * [new branch]      master     -> origin/master
# Already up to date.

# %%
# !git config user.name "jzhang-0"
# !git config user.email "jzhang__1999@outlook.com"
# !git add .
# !git commit -m "add git.ipynb"

# %%
# !git push
# Out:
# fatal: The current branch master has no upstream branch.
# To push the current branch and set the remote as upstream, use
#
#     git push --set-upstream origin master

# %%
# !git push -u origin master
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address

# %%
username = "jzhang-0"
git_token = "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"
rep = "cs231n_2021"

# %%
# !git remote rm origin
# !git remote add origin https://{git_token}@github.com/{username}/{rep}.git
# !git remote -v
# !git push -u origin master
# Out:
# origin	https://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@github.com/jzhang-0/cs231n_2021.git (fetch)
# origin	https://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@github.com/jzhang-0/cs231n_2021.git (push)

# %%
# !git push -u origin master
